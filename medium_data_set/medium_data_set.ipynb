# %%
# IMDB basierstes Data Set
# https://medium.com/analytics-vidhya/data-analysis-end-to-end-imdb-dataset-2b6d9976ebc2

# %%
import pandas as pd
import numpy as np

# %%
## Souce deleted
medium_df = pd.read_csv("")

# %%
# Test Data Set after import
medium_df.sample(30)
# Out:
#                                   Title  title_year     budget      Gross  \
# 57                             The Town        2010   37000000   92173235
# 73                            127 Hours        2010   18000000   18329466
# 43                            Gone Girl        2014   61000000  167735396
# 21       Dawn of the Planet of the Apes        2014  170000000  208543795
# 74                    Midnight in Paris        2011   17000000   56816662
# 89                                Amour        2012    8900000     225377
# 28                   X-Men: First Class        2011  160000000  146405371
# 55                            True Grit        2010   38000000  171031347
# 64                          The Fighter        2010   25000000   93571803
# 78             The Theory of Everything        2014   15000000   35887263
# 53                   The Social Network        2010   40000000   96917897
# 47                             Deadpool        2016   58000000  363024263
# ...

# %%
medium_df.shape
# Out:
# (100, 62)
